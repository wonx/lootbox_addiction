# %% [markdown]
# # Translation and Price scraping
#
# This notebook is essentially a cleaner version of features.ipynb
#
# From https://wiki.cs.money
#
# Translating lootbox content (Chinese to English)
#
# This website seems to have all the names in English and Chinese, with the estimated value for each outcome: https://wiki.cs.money/capsules
#
# e.g.: 印花 | apEX（闪耀） | 2022年安特卫普锦标赛 --> Sticker | apEX (Glitter) | Antwerp 2022
#
# Maybe we could find a way to scrape the data? For instance, to search: https://wiki.cs.money/search?q=2022%E5%B9%B4%E9%87%8C%E7%BA%A6%E7%83%AD%E5%86%85%E5%8D%A2%E9%94%A6%E6%A0%87%E8%B5%9B%E5%86%A0%E5%86%9B%E4%BA%B2%E7%AC%94%E7%AD%BE%E5%90%8D%E8%83%B6%E5%9B%8A

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ## Scraping lootbox outcomes (`df_out`)

# %% [markdown]
# ### Scraping weapon skins (`df_out_weaponskins`)

# %% [markdown]
# #### Scraping weapon types
#
# The idea is to first scrape the weapon types in English, then in Chinese, and then merge the two dataframes (`df_weapontypes_en` & `df_Weapontypes_zh` into a single one: `df_weapontypes`. This will be the skeleton in which the next dataframes will be built, since each weapon skin will correspond to one of these weapon types.

# %% [markdown]
# Using BeautifulSoup, scrape the weapon types in English to `df_weapontypes_en`.

# %%
# Make a request to the website
url = 'https://wiki.cs.money'
response = requests.get(url)

# Parse the HTML of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Initialize dataframe
df_weapontypes_en = pd.DataFrame(columns=['Type_en', 'Weapon_en', 'Image', 'Link'])

# Find the element containing all the data
data_element = soup.find('div', class_='vlcjlpdimswrcghpmhnvuiucwc')

# Find all the elements containing the weapon type
type_elements = data_element.find_all('div', class_='yubwxbvslulbauytxdhyofbyjh')

# Iterate over the weapon types
for type_element in type_elements:

    type_name_element = type_element.find('div', class_='dhpekapuyjhykzpqkkagxicxzl')
    type_ = type_name_element.get_text()
    
    # Find all the elements containing a weapon
    weapon_elements = type_element.find_all('div', class_='brzpbogxsgrlikcnlwpafrzdyt')
    
    # Iterate over the weapons
    for weapon_element in weapon_elements:
        # Find the elements containing the weapon name, link, and image
        name_element = weapon_element.find('div', class_='yuevqsquaveulqpticinqpvght')
        link_element = weapon_element.find('a', class_='itixalfiylvsvmdssbpcdzfawb')
        image_element = weapon_element.find('img', class_='djzvxzseplffnklcorsqbipwky')
        
        # Extract the data from the elements
        name = name_element.get_text()
        link = link_element['href']
        link = url+link
        image = image_element['src']
        image = url+image
        
        # Print the data
        #print(type_, name, link, image)
        df_weapontypes_en.loc[len(df_weapontypes_en)] = [type_, name, image, link]

display(df_weapontypes_en.sample(5))
# Out:
#    Type_en         Weapon_en  \
# 19  Rifles             AK-47
# 17  Knives    ★ Navaja Knife
# 20  Rifles               AWP
# 28  Rifles           SCAR-20
# 11  Knives  ★ Survival Knife
#
#                                                 Image  \
# 19  https://wiki.cs.money/_next/static/images/ak-4...
# 17  https://wiki.cs.money/_next/static/images/nava...
# 20  https://wiki.cs.money/_next/static/images/awp-...
# 28  https://wiki.cs.money/_next/static/images/scar...
# 11  https://wiki.cs.money/_next/static/images/surv...
#
#                                             Link
# 19           https://wiki.cs.money/weapons/ak-47
# 17    https://wiki.cs.money/weapons/navaja-knife
# 20             https://wiki.cs.money/weapons/awp
# 28         https://wiki.cs.money/weapons/scar-20
# 11  https://wiki.cs.money/weapons/survival-knife

# %% [markdown]
# Scrape weapon types in chinese to `df_weapontypes_zh`.

# %%
# Make a request to the website
url = 'https://wiki.cs.money'
suffix = '/zh'
response = requests.get(url+suffix)

# Parse the HTML of the page
soup = BeautifulSoup(response.text, 'html.parser')


# Initialize dataframe
df_weapontypes_zh = pd.DataFrame(columns=['Type_zh', 'Weapon_zh', 'Image_zh', 'Link_zh'])

# Find the element containing all the data
data_element = soup.find('div', class_='vlcjlpdimswrcghpmhnvuiucwc')

# Find all the elements containing the weapon type
type_elements = data_element.find_all('div', class_='yubwxbvslulbauytxdhyofbyjh')

# Iterate over the weapon types
for type_element in type_elements:

    type_name_element = type_element.find('div', class_='dhpekapuyjhykzpqkkagxicxzl')
    type_ = type_name_element.get_text()
    
    # Find all the elements containing a weapon
    weapon_elements = type_element.find_all('div', class_='brzpbogxsgrlikcnlwpafrzdyt')
    
    # Iterate over the weapons
    for weapon_element in weapon_elements:
        # Find the elements containing the weapon name, link, and image
        name_element = weapon_element.find('div', class_='yuevqsquaveulqpticinqpvght')
        link_element = weapon_element.find('a', class_='itixalfiylvsvmdssbpcdzfawb')
        image_element = weapon_element.find('img', class_='djzvxzseplffnklcorsqbipwky')
        
        # Extract the data from the elements
        name = name_element.get_text()
        link = link_element['href']
        link = url+link
        image = image_element['src']
        image = url+image
        
        # Print the data
        #print(type_, name, link, image)
        df_weapontypes_zh.loc[len(df_weapontypes_zh)] = [type_, name, image, link]

display(df_weapontypes_zh.sample(5))
# Out:
#    Type_zh Weapon_zh                                           Image_zh  \
# 21      步枪      M4A4  https://wiki.cs.money/_next/static/images/m4a4...
# 0        刀    爪子刀（★）  https://wiki.cs.money/_next/static/images/kara...
# 39      手枪     双持贝瑞塔  https://wiki.cs.money/_next/static/images/dual...
# 10       刀  流浪者匕首（★）  https://wiki.cs.money/_next/static/images/noma...
# 34      手枪      FN57  https://wiki.cs.money/_next/static/images/five...
#
#                                            Link_zh
# 21           https://wiki.cs.money/zh/weapons/m4a4
# 0        https://wiki.cs.money/zh/weapons/karambit
# 39  https://wiki.cs.money/zh/weapons/dual-berettas
# 10    https://wiki.cs.money/zh/weapons/nomad-knife
# 34     https://wiki.cs.money/zh/weapons/five-seven

# %% [markdown]
# Merge the two weapon type dataframes into `df_weapontypes`.

# %%
#df = pd.DataFrame(columns=['Type_en', 'Weapon_en', 'Image', 'Link'])
df_weapontypes  = pd.concat([df_weapontypes_en, df_weapontypes_zh], sort=False, axis=1)
df_weapontypes = df_weapontypes[['Type_en', 'Type_zh', 'Weapon_en', 'Weapon_zh', 'Image', 'Link']]
display(df_weapontypes)

# no longer needed, their contents are in df_weapons
del df_weapontypes_zh
del df_weapontypes_en
# Out:
#     Type_en Type_zh          Weapon_en  Weapon_zh  \
# 0    Knives       刀         ★ Karambit     爪子刀（★）
# 1    Knives       刀       ★ M9 Bayonet   M9 刺刀（★）
# 2    Knives       刀  ★ Butterfly Knife     蝴蝶刀（★）
# 3    Knives       刀      ★ Talon Knife    锯齿爪刀（★）
# 4    Knives       刀   ★ Skeleton Knife    骷髅匕首（★）
# 5    Knives       刀    ★ Classic Knife    海豹短刀（★）
# 6    Knives       刀          ★ Bayonet      刺刀（★）
# 7    Knives       刀   ★ Stiletto Knife      短剑（★）
# 8    Knives       刀      ★ Ursus Knife      熊刀（★）
# 9    Knives       刀   ★ Paracord Knife    系绳匕首（★）
# 10   Knives       刀      ★ Nomad Knife   流浪者匕首（★）
# 11   Knives       刀   ★ Survival Knife    求生匕首（★）
# 12   Knives       刀   ★ Huntsman Knife   猎杀者匕首（★）
# 13   Knives       刀       ★ Flip Knife     折叠刀（★）
# 14   Knives       刀      ★ Bowie Knife    鲍伊猎刀（★）
# 15   Knives       刀   ★ Falchion Knife      弯刀（★）
# 16   Knives       刀        ★ Gut Knife     穿肠刀（★）
# 17   Knives       刀     ★ Navaja Knife      折刀（★）
# 18   Knives       刀   ★ Shadow Daggers    暗影双匕（★）
# 19   Rifles      步枪              AK-47      AK-47
# 20   Rifles      步枪                AWP        AWP
# 21   Rifles      步枪               M4A4       M4A4
# 22   Rifles      步枪             M4A1-S   M4A1 消音版
# 23   Rifles      步枪                AUG        AUG
# 24   Rifles      步枪             SG 553     SG 553
# 25   Rifles      步枪           Galil AR     加利尔 AR
# 26   Rifles      步枪              FAMAS        法玛斯
# 27   Rifles      步枪             SSG 08     SSG 08
# 28   Rifles      步枪            SCAR-20    SCAR-20
# 29   Rifles      步枪              G3SG1      G3SG1
# 30  Pistols      手枪              USP-S    USP 消音版
# 31  Pistols      手枪           Glock-18   格洛克 18 型
# 32  Pistols      手枪       Desert Eagle       沙漠之鹰
# 33  Pistols      手枪               P250       P250
# 34  Pistols      手枪         Five-SeveN       FN57
# 35  Pistols      手枪          CZ75-Auto  CZ75 自动手枪
# 36  Pistols      手枪              P2000      P2000
# 37  Pistols      手枪              Tec-9      Tec-9
# 38  Pistols      手枪        R8 Revolver    R8 左轮手枪
# 39  Pistols      手枪      Dual Berettas      双持贝瑞塔
# 40     SMGs   微型冲锋枪                P90        P90
# 41     SMGs   微型冲锋枪             UMP-45     UMP-45
# 42     SMGs   微型冲锋枪             MAC-10     MAC-10
# 43     SMGs   微型冲锋枪                MP7        MP7
# 44     SMGs   微型冲锋枪                MP9        MP9
# 45     SMGs   微型冲锋枪             MP5-SD     MP5-SD
# 46     SMGs   微型冲锋枪           PP-Bizon      PP-野牛
# 47    Heavy    重型武器          Sawed-Off      截短霰弹枪
# 48    Heavy    重型武器              MAG-7      MAG-7
# 49    Heavy    重型武器               Nova         新星
# 50    Heavy    重型武器             XM1014     XM1014
# 51    Heavy    重型武器              Negev        内格夫
# 52    Heavy    重型武器               M249       M249
#
#                                                 Image  \
# 0   https://wiki.cs.money/_next/static/images/kara...
# 1   https://wiki.cs.money/_next/static/images/m9-b...
# 2   https://wiki.cs.money/_next/static/images/butt...
# 3   https://wiki.cs.money/_next/static/images/talo...
# 4   https://wiki.cs.money/_next/static/images/skel...
# 5   https://wiki.cs.money/_next/static/images/clas...
# 6   https://wiki.cs.money/_next/static/images/bayo...
# 7   https://wiki.cs.money/_next/static/images/stil...
# 8   https://wiki.cs.money/_next/static/images/ursu...
# 9   https://wiki.cs.money/_next/static/images/para...
# 10  https://wiki.cs.money/_next/static/images/noma...
# 11  https://wiki.cs.money/_next/static/images/surv...
# 12  https://wiki.cs.money/_next/static/images/hunt...
# 13  https://wiki.cs.money/_next/static/images/flip...
# 14  https://wiki.cs.money/_next/static/images/bowi...
# 15  https://wiki.cs.money/_next/static/images/falc...
# 16  https://wiki.cs.money/_next/static/images/gut-...
# 17  https://wiki.cs.money/_next/static/images/nava...
# 18  https://wiki.cs.money/_next/static/images/shad...
# 19  https://wiki.cs.money/_next/static/images/ak-4...
# 20  https://wiki.cs.money/_next/static/images/awp-...
# 21  https://wiki.cs.money/_next/static/images/m4a4...
# 22  https://wiki.cs.money/_next/static/images/m4a1...
# 23  https://wiki.cs.money/_next/static/images/aug-...
# 24  https://wiki.cs.money/_next/static/images/sg-5...
# 25  https://wiki.cs.money/_next/static/images/gali...
# 26  https://wiki.cs.money/_next/static/images/fama...
# 27  https://wiki.cs.money/_next/static/images/ssg-...
# 28  https://wiki.cs.money/_next/static/images/scar...
# 29  https://wiki.cs.money/_next/static/images/g3sg...
# 30  https://wiki.cs.money/_next/static/images/usp-...
# 31  https://wiki.cs.money/_next/static/images/gloc...
# 32  https://wiki.cs.money/_next/static/images/dese...
# 33  https://wiki.cs.money/_next/static/images/p250...
# 34  https://wiki.cs.money/_next/static/images/five...
# 35  https://wiki.cs.money/_next/static/images/cz75...
# 36  https://wiki.cs.money/_next/static/images/p200...
# 37  https://wiki.cs.money/_next/static/images/tec-...
# 38  https://wiki.cs.money/_next/static/images/r8-r...
# 39  https://wiki.cs.money/_next/static/images/dual...
# 40  https://wiki.cs.money/_next/static/images/p90-...
# 41  https://wiki.cs.money/_next/static/images/ump-...
# 42  https://wiki.cs.money/_next/static/images/mac-...
# 43  https://wiki.cs.money/_next/static/images/mp7-...
# 44  https://wiki.cs.money/_next/static/images/mp9-...
# 45  https://wiki.cs.money/_next/static/images/mp5-...
# 46  https://wiki.cs.money/_next/static/images/pp-b...
# 47  https://wiki.cs.money/_next/static/images/sawe...
# 48  https://wiki.cs.money/_next/static/images/mag-...
# 49  https://wiki.cs.money/_next/static/images/nova...
# 50  https://wiki.cs.money/_next/static/images/xm10...
# 51  https://wiki.cs.money/_next/static/images/nege...
# 52  https://wiki.cs.money/_next/static/images/m249...
#
#                                              Link
# 0          https://wiki.cs.money/weapons/karambit
# 1        https://wiki.cs.money/weapons/m9-bayonet
# 2   https://wiki.cs.money/weapons/butterfly-knife
# 3       https://wiki.cs.money/weapons/talon-knife
# 4    https://wiki.cs.money/weapons/skeleton-knife
# 5     https://wiki.cs.money/weapons/classic-knife
# 6           https://wiki.cs.money/weapons/bayonet
# 7    https://wiki.cs.money/weapons/stiletto-knife
# 8       https://wiki.cs.money/weapons/ursus-knife
# 9    https://wiki.cs.money/weapons/paracord-knife
# 10      https://wiki.cs.money/weapons/nomad-knife
# 11   https://wiki.cs.money/weapons/survival-knife
# 12   https://wiki.cs.money/weapons/huntsman-knife
# 13       https://wiki.cs.money/weapons/flip-knife
# 14      https://wiki.cs.money/weapons/bowie-knife
# 15   https://wiki.cs.money/weapons/falchion-knife
# 16        https://wiki.cs.money/weapons/gut-knife
# 17     https://wiki.cs.money/weapons/navaja-knife
# 18   https://wiki.cs.money/weapons/shadow-daggers
# 19            https://wiki.cs.money/weapons/ak-47
# 20              https://wiki.cs.money/weapons/awp
# 21             https://wiki.cs.money/weapons/m4a4
# 22           https://wiki.cs.money/weapons/m4a1-s
# 23              https://wiki.cs.money/weapons/aug
# 24           https://wiki.cs.money/weapons/sg-553
# 25         https://wiki.cs.money/weapons/galil-ar
# 26            https://wiki.cs.money/weapons/famas
# 27           https://wiki.cs.money/weapons/ssg-08
# 28          https://wiki.cs.money/weapons/scar-20
# 29            https://wiki.cs.money/weapons/g3sg1
# 30            https://wiki.cs.money/weapons/usp-s
# 31         https://wiki.cs.money/weapons/glock-18
# 32     https://wiki.cs.money/weapons/desert-eagle
# 33             https://wiki.cs.money/weapons/p250
# 34       https://wiki.cs.money/weapons/five-seven
# 35        https://wiki.cs.money/weapons/cz75-auto
# 36            https://wiki.cs.money/weapons/p2000
# 37            https://wiki.cs.money/weapons/tec-9
# 38      https://wiki.cs.money/weapons/r8-revolver
# 39    https://wiki.cs.money/weapons/dual-berettas
# 40              https://wiki.cs.money/weapons/p90
# 41           https://wiki.cs.money/weapons/ump-45
# 42           https://wiki.cs.money/weapons/mac-10
# 43              https://wiki.cs.money/weapons/mp7
# 44              https://wiki.cs.money/weapons/mp9
# 45           https://wiki.cs.money/weapons/mp5-sd
# 46         https://wiki.cs.money/weapons/pp-bizon
# 47        https://wiki.cs.money/weapons/sawed-off
# 48            https://wiki.cs.money/weapons/mag-7
# 49             https://wiki.cs.money/weapons/nova
# 50           https://wiki.cs.money/weapons/xm1014
# 51            https://wiki.cs.money/weapons/negev
# 52             https://wiki.cs.money/weapons/m249

# %% [markdown]
# #### Scraping weapon skins
#
#
# ##### Helper functions
#
# ###### Smooth scrolling `smooth_scroll()`
# Since some parts of the website use infinite scrolling to load the content, some helper functions are used in order to scrape the data. Google Chrome needs to be installed in the system for this task.

# %%
## Smooth scroller for webs that load with infinite scrolling
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

def smooth_scroll(url):
    chrome_options = Options()
    chrome_options.add_argument("--incognito")
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url)
    time.sleep(2) # Wait for the website to load

    reached_page_end = False
    last_height = driver.execute_script("return window.pageYOffset + window.innerHeight")

    time.sleep(2)
    scroll_distance = 10

    while not reached_page_end:
        driver.execute_script(f"window.scrollBy(0, {scroll_distance});")
        time.sleep(0.5) 
        pageHeight = driver.execute_script("return document.body.scrollHeight")
        new_height = driver.execute_script("return window.pageYOffset + window.innerHeight")

        if last_height == new_height:
                reached_page_end = True
                print("reached end")
        else:
                last_height = new_height
                scroll_distance += 5
    html = driver.page_source           
    driver.close()
    return html

# %% [markdown]
# ###### Convert URL to the English to Chinese version `convert_url()`
# Some parts of the website use a common URL for the Chinese and English parts, with the difference of a small particle indicating the language. This function converts the English to the Chinese version of URL.
#
# For instance, https://wiki.cs.money/weapons/aug --> https://wiki.cs.money/zh/weapons/aug.

# %%
# Function to handle the URL language conversion
def convert_url(url, language_code):
    # Split the URL into its components
    protocol, domain_and_path = url.split("://", 1)
    domain, path = domain_and_path.split("/", 1)
    
    # Check if the path starts with a language code
    if path.startswith("[language code]/"):
        # If it does, replace the language code with the desired language code
        modified_path = path.replace("[language code]", language_code, 1)
    else:
        # If it doesn't, add the desired language code at the beginning of the path
        modified_path = f"{language_code}/{path}"
    
    # Reassemble the URL
    modified_url = f"{protocol}://{domain}/{modified_path}"
    
    return modified_url

# %% [markdown]
# ###### Scrape skin info `get_skin_info()`
#
# Obtains the information about the skin info from the URL of the website for both the English and Chinese versions. Returns a dataframe: `df_skins`

# %%
# Returns df with info about specific weapon, from an URL
def get_skin_info(url):

    # Make a request to the website
    baseurl = 'https://wiki.cs.money'

    
    # Parse the HTML of the page
    ## First, check if it's one of these pages that require infinite scrolling or not
    needs_infinitescroll = ['regular-stickers', 'tournament-stickers', 'patches', 'graffiti', 'pins']
    if any(string in url for string in needs_infinitescroll):
        soup = BeautifulSoup(smooth_scroll(url), 'html.parser')
    else:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')


    # Initialize dataframe
    df_skins = pd.DataFrame(columns=['Weapon_en', 'Skin_Name', 'Grade', 'Rarity', 'Value', 'Value_Stattrak', 'Value_Souvenir', 'Skin_Link', 'Found_in', 'Found_in_Link'])

    # Find the element containing all the data
    data_element = soup.find('div', class_='gasovxczmdwrpzliptyovkjrjp')

    skin_elements = data_element.find_all('div', class_='kxmatkcipwonxvwweiqqdoumxg') # In some rare cases, it can be empty
    #if data_element is not None:
    #    skin_elements = data_element.find_all('div', class_='kxmatkcipwonxvwweiqqdoumxg')
    #else:
    #    skin_elements = []

    grade_rarity = {
        'Consumer Grade':1, 
        'Base Grade':1,
        'Default':1,
        'Normal':1,
        'Industrial Grade':2,
        'Mil-Spec':3,
        'High Grade':3,
        'Distinguished':3,
        'Restricted':4,
        'Remarkable':4,
        'Exceptional':4,
        'Classified':5,
        'Exotic':5,
        'Superior':5,
        'Covert':6,
        'Extraordinary':6,
        'Master':6,
        'Rare Special (★)':7,
        'Knife':7,
        'Gloves':7,
        'Contraband':8,
        '★ StatTrak™':4,
        'StatTrak™':np.nan,
        'Souvenir':np.nan
    }

    # Iterate over the skins
    for skin_element in skin_elements:
        weapon_element = skin_element.find('div', class_='szvsuisjrrqalciyqqzoxoaubw') 
        name_element = skin_element.find('div', class_='zhqwubnajobxbgkzlnptmjmgwn')
        link_element = skin_element.find('a', class_='blzuifkxmlnzwzwpwjzrrtwcse')
        grade_element = skin_element.find_all('div', class_='nwdmbwsohrhpxvdldicoixwfed') # Each grade is associated with a color. Can be a single element or (more commonly) a list of elements.

        foundin_element = skin_element.find('div', class_='vercanrflftqkxuojwkgkgsiak') # Can either be a single item (e.g. collection) or a list of cases where it can be found. Can also be empty
        foundin_item_elements = skin_element.find_all('li', class_='ovgyowuqvvytpzvkyvdijroyub') # sometimes foundin_element might contain more than one subitem
        foundin_link_elements = skin_element.find_all('a', class_='wszrcfrvpibgonenagkdwmyscg')  # There is a link for each element of "found in"

        value_element = skin_element.find('div', class_='ribvzntfjepldppjrgkwabviqq') #might be empty
        value_stattrak_element = skin_element.find('div', class_='ribvzntfjepldppjrgkwabviqq dqyspyiikxcwupdhcrxpbwlide') #might be empty
        value_souvenir_element = skin_element.find('div', class_='ribvzntfjepldppjrgkwabviqq sxupcdgqjermeuhxnaqmawnkmi') #might be empty
                
        # Extract the data from the elements
        weapon = weapon_element.get_text()
        name = name_element.get_text()
        #grade = grade_element[1]['title'] if len(grade_element) > 1 else grade_element[0]['title']
        grade = [element.get('title') for element in grade_element]
        #rarity = grade_rarity[grade]
        rarity = [grade_rarity[g] for g in grade] # will also be a list, a skin or object han appear in different grades
        if "★" in weapon: rarity[-1] +=1 #Increase the grade by 1 only to the last element of the list (the first one is the "normal" object).
        link = link_element['href']
        link = baseurl+link

        foundin = [foundin_element.get_text()] if foundin_element else []
        item_list = [item.get_text() for item in foundin_item_elements] # if there's more than one
        if item_list: foundin = item_list
        foundinlink = [baseurl+link['href'] for link in foundin_link_elements] # convert links for "Found in" items to list
        
        value = value_element.get_text() if value_element is not None else ""
        value_stattrak = value_stattrak_element.get_text() if value_stattrak_element is not None else ""
        value_souvenir = value_souvenir_element.get_text() if value_souvenir_element is not None else ""

        # Append to dataframe
        df_skins.loc[len(df_skins)] = [weapon, name, grade, rarity, value, value_stattrak, value_souvenir, link, foundin, foundinlink]



    #### Repeat the exact same procedure, but for the Chinese version of the site. We do not need to get the value again.
    # Make a request to the website
    # Extract the subdomain, domain, and path from the original URL
    lang = 'zh'
    url = convert_url(url, lang)
    baseurl = 'https://wiki.cs.money'
    print(url)
    
    # Parse the HTML of the page
    ## First, check if it's one of these pages that require infinite scrolling or not
    needs_infinitescroll = ['regular-stickers', 'tournament-stickers', 'patches', 'graffiti', 'pins']
    if any(string in url for string in needs_infinitescroll):
        soup = BeautifulSoup(smooth_scroll(url), 'html.parser')
    else:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize dataframe
    df_skins_zh = pd.DataFrame(columns=['Weapon_zh', 'Skin_Name_zh', 'Found_in_zh', 'Found_in_Link_zh'])

    # Find the element containing all the data
    data_element = soup.find('div', class_='gasovxczmdwrpzliptyovkjrjp')

    #skin_elements = data_element.find_all('div', class_='kxmatkcipwonxvwweiqqdoumxg') # In some rare cases, it can be empty
    if data_element is not None:
        skin_elements = data_element.find_all('div', class_='kxmatkcipwonxvwweiqqdoumxg')
    else:
        skin_elements = []
    
    # Iterate over the skins
    for skin_element in skin_elements:
        weapon_element = skin_element.find('div', class_='szvsuisjrrqalciyqqzoxoaubw') 
        name_element = skin_element.find('div', class_='zhqwubnajobxbgkzlnptmjmgwn')
        foundin_element = skin_element.find('div', class_='vercanrflftqkxuojwkgkgsiak')
        foundin_item_elements = skin_element.find_all('li', class_='ovgyowuqvvytpzvkyvdijroyub') # sometimes foundin_element might contain more than one subitem
        foundin_link_elements = skin_element.find_all('a', class_='wszrcfrvpibgonenagkdwmyscg')  # There is a link for each element of "found in"

        # Extract the data from the elements
        weapon = weapon_element.get_text()
        name = name_element.get_text()
        #if foundin_element: foundin = [foundin_element.get_text()] # In case there's just one element
        foundin = [foundin_element.get_text()] if foundin_element else []
        item_list = [item.get_text() for item in foundin_item_elements] # If there's more than one
        if item_list: foundin = item_list

        foundinlink = [baseurl+link['href'] for link in foundin_link_elements] # convert links for "Found in" items to list

        # Append to dataframe
        df_skins_zh.loc[len(df_skins_zh)] = [weapon, name, foundin, foundinlink]

    # And now concatenate the English and Chinese skin df into one
    df_skins  = pd.concat([df_skins, df_skins_zh], sort=False, axis=1)
    df_skins = df_skins[['Weapon_en', 'Weapon_zh', 'Skin_Name', 'Skin_Name_zh', 'Grade', 'Rarity', 'Value', 'Value_Stattrak', 'Value_Souvenir', 'Skin_Link', 'Found_in', 'Found_in_zh', 'Found_in_Link', 'Found_in_Link_zh']]
    

    return df_skins

# %% [markdown]
# ##### Actual scraping of the skins
#
# Loop through the weapontypes and scrape all the skins for each weapon. Save the results into a dataframe: `df_weaponskins`.

# %%
# This loop will get the skins for each one of the 53 weapons in df_weapontypes, both in English and in Chinese. Can take a while.
df_weaponskins = pd.DataFrame()
for weapon in df_weapontypes['Link']:
    print(weapon)
    df_weaponskins = pd.concat([df_weaponskins, get_skin_info(weapon)], axis=0)

display(df_weaponskins.sample(5))
# Out:
# https://wiki.cs.money/weapons/karambit
# https://wiki.cs.money/zh/weapons/karambit
# https://wiki.cs.money/weapons/m9-bayonet
# https://wiki.cs.money/zh/weapons/m9-bayonet
# https://wiki.cs.money/weapons/butterfly-knife
# https://wiki.cs.money/zh/weapons/butterfly-knife
# https://wiki.cs.money/weapons/talon-knife
# https://wiki.cs.money/zh/weapons/talon-knife
# https://wiki.cs.money/weapons/skeleton-knife
# https://wiki.cs.money/zh/weapons/skeleton-knife
# https://wiki.cs.money/weapons/classic-knife
# https://wiki.cs.money/zh/weapons/classic-knife
# https://wiki.cs.money/weapons/bayonet
# https://wiki.cs.money/zh/weapons/bayonet
# https://wiki.cs.money/weapons/stiletto-knife
# https://wiki.cs.money/zh/weapons/stiletto-knife
# https://wiki.cs.money/weapons/ursus-knife
# https://wiki.cs.money/zh/weapons/ursus-knife
# https://wiki.cs.money/weapons/paracord-knife
# https://wiki.cs.money/zh/weapons/paracord-knife
# https://wiki.cs.money/weapons/nomad-knife
# https://wiki.cs.money/zh/weapons/nomad-knife
# https://wiki.cs.money/weapons/survival-knife
# https://wiki.cs.money/zh/weapons/survival-knife
# https://wiki.cs.money/weapons/huntsman-knife
# https://wiki.cs.money/zh/weapons/huntsman-knife
# https://wiki.cs.money/weapons/flip-knife
# https://wiki.cs.money/zh/weapons/flip-knife
# https://wiki.cs.money/weapons/bowie-knife
# https://wiki.cs.money/zh/weapons/bowie-knife
# https://wiki.cs.money/weapons/falchion-knife
# https://wiki.cs.money/zh/weapons/falchion-knife
# https://wiki.cs.money/weapons/gut-knife
# https://wiki.cs.money/zh/weapons/gut-knife
# https://wiki.cs.money/weapons/navaja-knife
# https://wiki.cs.money/zh/weapons/navaja-knife
# https://wiki.cs.money/weapons/shadow-daggers
# https://wiki.cs.money/zh/weapons/shadow-daggers
# https://wiki.cs.money/weapons/ak-47
# https://wiki.cs.money/zh/weapons/ak-47
# https://wiki.cs.money/weapons/awp
# https://wiki.cs.money/zh/weapons/awp
# https://wiki.cs.money/weapons/m4a4
# https://wiki.cs.money/zh/weapons/m4a4
# https://wiki.cs.money/weapons/m4a1-s
# https://wiki.cs.money/zh/weapons/m4a1-s
# https://wiki.cs.money/weapons/aug
# https://wiki.cs.money/zh/weapons/aug
# https://wiki.cs.money/weapons/sg-553
# https://wiki.cs.money/zh/weapons/sg-553
# https://wiki.cs.money/weapons/galil-ar
# https://wiki.cs.money/zh/weapons/galil-ar
# https://wiki.cs.money/weapons/famas
# https://wiki.cs.money/zh/weapons/famas
# https://wiki.cs.money/weapons/ssg-08
# https://wiki.cs.money/zh/weapons/ssg-08
# https://wiki.cs.money/weapons/scar-20
# https://wiki.cs.money/zh/weapons/scar-20
# https://wiki.cs.money/weapons/g3sg1
# https://wiki.cs.money/zh/weapons/g3sg1
# https://wiki.cs.money/weapons/usp-s
# https://wiki.cs.money/zh/weapons/usp-s
# https://wiki.cs.money/weapons/glock-18
# https://wiki.cs.money/zh/weapons/glock-18
# https://wiki.cs.money/weapons/desert-eagle
# https://wiki.cs.money/zh/weapons/desert-eagle
# https://wiki.cs.money/weapons/p250
# https://wiki.cs.money/zh/weapons/p250
# https://wiki.cs.money/weapons/five-seven
# https://wiki.cs.money/zh/weapons/five-seven
# https://wiki.cs.money/weapons/cz75-auto
# https://wiki.cs.money/zh/weapons/cz75-auto
# https://wiki.cs.money/weapons/p2000
# https://wiki.cs.money/zh/weapons/p2000
# https://wiki.cs.money/weapons/tec-9
# https://wiki.cs.money/zh/weapons/tec-9
# https://wiki.cs.money/weapons/r8-revolver
# https://wiki.cs.money/zh/weapons/r8-revolver
# https://wiki.cs.money/weapons/dual-berettas
# https://wiki.cs.money/zh/weapons/dual-berettas
# https://wiki.cs.money/weapons/p90
# https://wiki.cs.money/zh/weapons/p90
# https://wiki.cs.money/weapons/ump-45
# https://wiki.cs.money/zh/weapons/ump-45
# https://wiki.cs.money/weapons/mac-10
# https://wiki.cs.money/zh/weapons/mac-10
# https://wiki.cs.money/weapons/mp7
# https://wiki.cs.money/zh/weapons/mp7
# https://wiki.cs.money/weapons/mp9
# https://wiki.cs.money/zh/weapons/mp9
# https://wiki.cs.money/weapons/mp5-sd
# https://wiki.cs.money/zh/weapons/mp5-sd
# https://wiki.cs.money/weapons/pp-bizon
# https://wiki.cs.money/zh/weapons/pp-bizon
# https://wiki.cs.money/weapons/sawed-off
# https://wiki.cs.money/zh/weapons/sawed-off
# https://wiki.cs.money/weapons/mag-7
# https://wiki.cs.money/zh/weapons/mag-7
# https://wiki.cs.money/weapons/nova
# https://wiki.cs.money/zh/weapons/nova
# https://wiki.cs.money/weapons/xm1014
# https://wiki.cs.money/zh/weapons/xm1014
# https://wiki.cs.money/weapons/negev
# https://wiki.cs.money/zh/weapons/negev
# https://wiki.cs.money/weapons/m249
# https://wiki.cs.money/zh/weapons/m249
#        Weapon_en Weapon_zh              Skin_Name Skin_Name_zh  \
# 6   ★ M9 Bayonet  M9 刺刀（★）  Gamma Doppler Phase 2    伽玛多普勒阶段 2
# 32    Five-SeveN      FN57           Forest Night         暮色森林
# 24        SSG 08    SSG 08              Acid Fade         渐变强酸
# 25      Glock-18  格洛克 18 型       Steel Disruption         钢铁禁锢
# 0    R8 Revolver   R8 左轮手枪                   Fade         渐变之色
#
#                          Grade    Rarity                    Value  \
# 6        [★ StatTrak™, Covert]    [4, 7]  $ 1 399.33 - $ 1 879.72
# 32  [Souvenir, Consumer Grade]  [nan, 1]          $ 0.03 - $ 0.13
# 24        [Souvenir, Mil-Spec]  [nan, 3]                   $ 1.62
# 25     [StatTrak™, Restricted]  [nan, 4]          $ 2.13 - $ 2.92
# 0          [StatTrak™, Covert]  [nan, 6]         $ 4.73 - $ 14.26
#
#        Value_Stattrak   Value_Souvenir  \
# 6          $ 1 719.08
# 32                     $ 0.26 - $ 6.77
# 24
# 25    $ 4.89 - $ 6.81
# 0   $ 15.14 - $ 55.36
#
#                                             Skin_Link  \
# 6   https://wiki.cs.money/weapons/m9-bayonet/gamma...
# 32  https://wiki.cs.money/weapons/five-seven/fores...
# 24     https://wiki.cs.money/weapons/ssg-08/acid-fade
# 25  https://wiki.cs.money/weapons/glock-18/steel-d...
# 0      https://wiki.cs.money/weapons/r8-revolver/fade
#
#                                 Found_in         Found_in_zh  \
# 6             [Gamma 2 Case, Gamma Case]  [伽玛 2 号武器箱, 伽玛武器箱]
# 32                [The Train Collection]          [列车停放站收藏品]
# 24            [The Safehouse Collection]           [安全处所收藏品]
# 25  [The eSports 2014 Summer Collection]     [电竞 2014 夏季收藏品]
# 0         [The Revolver Case Collection]          [左轮武器箱收藏品]
#
#                                         Found_in_Link  \
# 6   [https://wiki.cs.money/cases/gamma-2-case, htt...
# 32  [https://wiki.cs.money/collections/the-train-c...
# 24  [https://wiki.cs.money/collections/the-safehou...
# 25  [https://wiki.cs.money/collections/the-esports...
# 0   [https://wiki.cs.money/collections/the-revolve...
#
#                                      Found_in_Link_zh
# 6   [https://wiki.cs.money/zh/cases/gamma-2-case, ...
# 32  [https://wiki.cs.money/zh/collections/the-trai...
# 24  [https://wiki.cs.money/zh/collections/the-safe...
# 25  [https://wiki.cs.money/zh/collections/the-espo...
# 0   [https://wiki.cs.money/zh/collections/the-revo...

# %% [markdown]
# #### Merge the Weapon types `df_weapontypes` and Weapon Skins `df_weaponskins` dataframes

# %%
df_out_weaponskins = df_weapontypes.copy()

df_out_weaponskins = df_out_weaponskins.merge(df_weaponskins, how='outer', left_on=['Weapon_en', 'Weapon_zh'], right_on=['Weapon_en', 'Weapon_zh'])
display(df_out_weaponskins.sample(7))

# no longer needed
del df_weaponskins
del df_weapontypes

# Let's save the df to a file
import os
if not os.path.exists('df_pickles'):
   os.makedirs('df_pickles')

df_out_weaponskins.to_pickle("./df_pickles/df_out_weaponskins.pkl")
# Out:
#       Type_en Type_zh       Weapon_en Weapon_zh  \
# 971   Pistols      手枪    Desert Eagle      沙漠之鹰
# 868    Rifles      步枪           G3SG1     G3SG1
# 477    Knives       刀  ★ Navaja Knife     折刀（★）
# 1126  Pistols      手枪           P2000     P2000
# 539    Rifles      步枪           AK-47     AK-47
# 1588    Heavy    重型武器           Negev       内格夫
# 1276     SMGs   微型冲锋枪          UMP-45    UMP-45
# 41     Knives       刀    ★ M9 Bayonet  M9 刺刀（★）
# 706    Rifles      步枪          SG 553    SG 553
# 1400     SMGs   微型冲锋枪             MP9       MP9
#
#                                                   Image  \
# 971   https://wiki.cs.money/_next/static/images/dese...
# 868   https://wiki.cs.money/_next/static/images/g3sg...
# 477   https://wiki.cs.money/_next/static/images/nava...
# 1126  https://wiki.cs.money/_next/static/images/p200...
# 539   https://wiki.cs.money/_next/static/images/ak-4...
# 1588  https://wiki.cs.money/_next/static/images/nege...
# 1276  https://wiki.cs.money/_next/static/images/ump-...
# 41    https://wiki.cs.money/_next/static/images/m9-b...
# 706   https://wiki.cs.money/_next/static/images/sg-5...
# 1400  https://wiki.cs.money/_next/static/images/mp9-...
#
#                                             Link              Skin_Name  \
# 971   https://wiki.cs.money/weapons/desert-eagle      Cobalt Disruption
# 868          https://wiki.cs.money/weapons/g3sg1         Ancient Ritual
# 477   https://wiki.cs.money/weapons/navaja-knife                Stained
# 1126         https://wiki.cs.money/weapons/p2000                   Turf
# 539          https://wiki.cs.money/weapons/ak-47        Frontside Misty
# 1588         https://wiki.cs.money/weapons/negev               Bratatat
# 1276        https://wiki.cs.money/weapons/ump-45              Mechanism
# 41      https://wiki.cs.money/weapons/m9-bayonet  Gamma Doppler Phase 2
# 706         https://wiki.cs.money/weapons/sg-553                Tornado
# 1400           https://wiki.cs.money/weapons/mp9             Army Sheen
#
#      Skin_Name_zh                         Grade    Rarity  \
# 971          钴蓝禁锢       [StatTrak™, Classified]  [nan, 5]
# 868          远古仪式  [Souvenir, Industrial Grade]  [nan, 2]
# 477          人工染色         [★ StatTrak™, Covert]    [4, 7]
# 1126           草皮         [StatTrak™, Mil-Spec]  [nan, 3]
# 539          前线迷雾       [StatTrak™, Classified]  [nan, 5]
# 1588        *哒哒哒*         [StatTrak™, Mil-Spec]  [nan, 3]
# 1276         机械装置  [Souvenir, Industrial Grade]  [nan, 2]
# 41      伽玛多普勒阶段 2         [★ StatTrak™, Covert]    [4, 7]
# 706          狂哮飓风      [Normal, Consumer Grade]    [1, 1]
# 1400         军队之辉      [Normal, Consumer Grade]    [1, 1]
#
#                         Value      Value_Stattrak   Value_Souvenir  \
# 971         $ 51.34 - $ 66.16  $ 57.59 - $ 108.25
# 868           $ 0.72 - $ 1.20                      $ 0.06 - $ 0.51
# 477         $ 76.42 - $ 79.29  $ 68.75 - $ 166.51
# 1126          $ 0.10 - $ 0.66     $ 0.24 - $ 2.51
# 539         $ 11.36 - $ 54.56  $ 22.37 - $ 129.04
# 1588          $ 0.66 - $ 5.00    $ 1.15 - $ 17.63
# 1276          $ 1.24 - $ 1.77                      $ 0.22 - $ 0.48
# 41    $ 1 399.33 - $ 1 879.72          $ 1 719.08
# 706          $ 5.49 - $ 17.11
# 1400          $ 0.06 - $ 0.13
#
#                                               Skin_Link  \
# 971   https://wiki.cs.money/weapons/desert-eagle/cob...
# 868   https://wiki.cs.money/weapons/g3sg1/ancient-ri...
# 477   https://wiki.cs.money/weapons/navaja-knife/sta...
# 1126           https://wiki.cs.money/weapons/p2000/turf
# 539   https://wiki.cs.money/weapons/ak-47/frontside-...
# 1588       https://wiki.cs.money/weapons/negev/bratatat
# 1276     https://wiki.cs.money/weapons/ump-45/mechanism
# 41    https://wiki.cs.money/weapons/m9-bayonet/gamma...
# 706        https://wiki.cs.money/weapons/sg-553/tornado
# 1400       https://wiki.cs.money/weapons/mp9/army-sheen
#
#                                   Found_in          Found_in_zh  \
# 971             [eSports 2013 Winter Case]      [电竞 2013 冬季武器箱]
# 868               [The Ancient Collection]              [远古收藏品]
# 477       [Danger Zone Case, Horizon Case]  [“头号特训”武器箱, 地平线武器箱]
# 1126                [The Glove Collection]              [手套收藏品]
# 539                [The Shadow Collection]              [暗影收藏品]
# 1588  [The eSports 2014 Summer Collection]      [电竞 2014 夏季收藏品]
# 1276         [The 2021 Vertigo Collection]       [2021 殒命大厦收藏品]
# 41              [Gamma 2 Case, Gamma Case]   [伽玛 2 号武器箱, 伽玛武器箱]
# 706               [The Assault Collection]            [仓库突击收藏品]
# 1400              [The Control Collection]              [控制收藏品]
#
#                                           Found_in_Link  \
# 971   [https://wiki.cs.money/cases/esports-2013-wint...
# 868   [https://wiki.cs.money/collections/the-ancient...
# 477   [https://wiki.cs.money/cases/danger-zone-case,...
# 1126  [https://wiki.cs.money/collections/the-glove-c...
# 539   [https://wiki.cs.money/collections/the-shadow-...
# 1588  [https://wiki.cs.money/collections/the-esports...
# 1276  [https://wiki.cs.money/collections/the-2021-ve...
# 41    [https://wiki.cs.money/cases/gamma-2-case, htt...
# 706   [https://wiki.cs.money/collections/the-assault...
# 1400  [https://wiki.cs.money/collections/the-control...
#
#                                        Found_in_Link_zh
# 971   [https://wiki.cs.money/zh/cases/esports-2013-w...
# 868   [https://wiki.cs.money/zh/collections/the-anci...
# 477   [https://wiki.cs.money/zh/cases/danger-zone-ca...
# 1126  [https://wiki.cs.money/zh/collections/the-glov...
# 539   [https://wiki.cs.money/zh/collections/the-shad...
# 1588  [https://wiki.cs.money/zh/collections/the-espo...
# 1276  [https://wiki.cs.money/zh/collections/the-2021...
# 41    [https://wiki.cs.money/zh/cases/gamma-2-case, ...
# 706   [https://wiki.cs.money/zh/collections/the-assa...
# 1400  [https://wiki.cs.money/zh/collections/the-cont...

# %% [markdown]
# ### Scraping "Other" (`df_out_other`) (e.g. stickers, pins, graffiti...)
#
# Now, it's turn to do the same with 'Other'. (e.g. lootboxes outcomes that are not weapon skins). Basically, each category in `other_out` is comparable to a weapon (which will contain many "skins"). We'll merge the other dataframe with df_out, and then it will be a comprehensive table of the possible lootbox outcomes, and it will correspond to the `out` column in the json stream in the purchases csv (`output.csv`).

# %% [markdown]
# Skeleton of the `df_out_other` dataframe.
#
# The website is not very consistent, so there are many elements here that will be entered manually.

# %%
# Too chaotic in the website to scrape it automatically...

# list of outcome types from src, except weapon skins, and URLs
other_out_en = {
    'Gloves':'https://wiki.cs.money/gloves',
    'Keys':'https://wiki.cs.money/keys',
    #'Rare Patterns':'https://wiki.cs.money/rare-patterns',
    'Agents':'https://wiki.cs.money/agents',
    'Regular Stickers':'https://wiki.cs.money/regular-stickers',
    'Tournament Stickers':'https://wiki.cs.money/tournament-stickers',
    'Patches':'https://wiki.cs.money/patches',
    'Graffiti':'https://wiki.cs.money/graffiti',
    'Music Kits':'https://wiki.cs.money/music-kits',
    'Pins':'https://wiki.cs.money/pins'
} 
df_other_out_en = pd.DataFrame.from_dict(other_out_en, orient='index', columns=['Link'])
df_other_out_en.reset_index(inplace=True)
df_other_out_en = df_other_out_en.rename(columns={"index": "Type_en"})

other_out_zh = {
    '手套':'https://wiki.cs.money/zh/gloves',
    '钥匙':'https://wiki.cs.money/zh/keys',
    #'罕见的图案':'https://wiki.cs.money/zh/rare-patterns',
    '探员':'https://wiki.cs.money/zh/agents',
    '普通贴纸':'https://wiki.cs.money/zh/regular-stickers',
    '大赛贴纸':'https://wiki.cs.money/zh/tournament-stickers',
    '布章':'https://wiki.cs.money/zh/patches',
    '涂鸦':'https://wiki.cs.money/zh/graffiti',
    '音乐盒':'https://wiki.cs.money/zh/music-kits',
    '引脚':'https://wiki.cs.money/zh/pins'

}
df_other_out_zh = pd.DataFrame.from_dict(other_out_zh, orient='index', columns=['Link_zh'])
df_other_out_zh.reset_index(inplace=True)
df_other_out_zh = df_other_out_zh.rename(columns={"index": "Type_zh"})

# Concat the EN and ZH versions
df_other_out = pd.concat([df_other_out_en, df_other_out_zh], axis=1)

display(df_other_out)

# no longer needed
del other_out_en
del other_out_zh
del df_other_out_zh
del df_other_out_en

# (it's possible that the "Rare Patterns" are duplicates of skins already found on each weapon skin, and can be removed from the dict)
# Regular stickers has an infinite scroll page, but beautifulsoup can only capture the first 16 elements. We would need some javascript magic. Same with Pins. Check if there are other pages with the same issue.
## function smooth_scroll() implemented for this purpose. Can still fail if website loads too slowly (modify the parameters on the website in this case).
# Out:
#                Type_en                                       Link Type_zh  \
# 0               Gloves               https://wiki.cs.money/gloves      手套
# 1                 Keys                 https://wiki.cs.money/keys      钥匙
# 2               Agents               https://wiki.cs.money/agents      探员
# 3     Regular Stickers     https://wiki.cs.money/regular-stickers    普通贴纸
# 4  Tournament Stickers  https://wiki.cs.money/tournament-stickers    大赛贴纸
# 5              Patches              https://wiki.cs.money/patches      布章
# 6             Graffiti             https://wiki.cs.money/graffiti      涂鸦
# 7           Music Kits           https://wiki.cs.money/music-kits     音乐盒
# 8                 Pins                 https://wiki.cs.money/pins      引脚
#
#                                         Link_zh
# 0               https://wiki.cs.money/zh/gloves
# 1                 https://wiki.cs.money/zh/keys
# 2               https://wiki.cs.money/zh/agents
# 3     https://wiki.cs.money/zh/regular-stickers
# 4  https://wiki.cs.money/zh/tournament-stickers
# 5              https://wiki.cs.money/zh/patches
# 6             https://wiki.cs.money/zh/graffiti
# 7           https://wiki.cs.money/zh/music-kits
# 8                 https://wiki.cs.money/zh/pins

# %% [markdown]
# Actually scraping 'other' elements
#
# For each one of the types `df_other_out`, do what we did for the Skins for each type of weapon.
# Since sometimes the website has a tendency to not load properly, we'll save each dataframe as picke for each type, and we'll join them later.
#
# This part will open a webbrowser window and smooth scroll to the end of the page to load all items. Can be quite slow, so be patient.

# %%
# Usually takes aroun 20 minutes.
for index, row in df_other_out.iterrows():
    #print(index)
    print(row['Type_en'])
    print(row['Link'])
    new_df = get_skin_info(row['Link'])
    new_df['Type_en'] = row['Type_en']
    new_df.to_pickle("./df_pickles/new_df_{}.pkl".format(row['Type_en']))
    del new_df
# Out:
# Gloves
# https://wiki.cs.money/gloves
# https://wiki.cs.money/zh/gloves
# Keys
# https://wiki.cs.money/keys
# https://wiki.cs.money/zh/keys
# Agents
# https://wiki.cs.money/agents
# https://wiki.cs.money/zh/agents
# Regular Stickers
# https://wiki.cs.money/regular-stickers
# reached end
# https://wiki.cs.money/zh/regular-stickers
# reached end
# Tournament Stickers
# https://wiki.cs.money/tournament-stickers
# reached end
# https://wiki.cs.money/zh/tournament-stickers
# reached end
# Patches
# https://wiki.cs.money/patches
# reached end
# https://wiki.cs.money/zh/patches
# reached end
# Graffiti
# https://wiki.cs.money/graffiti
# reached end
# https://wiki.cs.money/zh/graffiti
# reached end
# Music Kits
# https://wiki.cs.money/music-kits
# https://wiki.cs.money/zh/music-kits
# Pins
# https://wiki.cs.money/pins
# reached end
# https://wiki.cs.money/zh/pins
# reached end

# %% [markdown]
# (In case of error, manually scrapping one particular element). One way to detect missing info is to compare if the number of non-null elements match in the English and Chinese version for the Weapon and Skin_name features. Beware that the website contains some inconsistencies. For instance, the field Skin_name_zh will appear in Weapon_zh for one particular patch.

# %%
# Just in case some of them failed (due to the smooth scrolling) and you need to rerun it manually. Example with "Patches"
new_df = get_skin_info('https://wiki.cs.money/patches')
new_df['Type_en'] = "Patches"
print(len(new_df))
new_df.to_pickle("./new_df_Patches.pkl")
del new_df

# %%
# Checking the number of non-null elements.
df_temp = pd.read_pickle("new_df_Patches.pkl")
df_temp.replace(r'^\s*$', np.nan, regex=True).info()
display(df_temp.sample(5))
del df_temp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 0 to 106
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Weapon_en         107 non-null    object
#  1   Weapon_zh         107 non-null    object
#  2   Skin_Name         50 non-null     object
#  3   Skin_Name_zh      48 non-null     object
#  4   Grade             107 non-null    object
#  5   Rarity            107 non-null    object
#  6   Value             107 non-null    object
#  7   Value_Stattrak    0 non-null      float64
#  8   Value_Souvenir    0 non-null      float64
#  9   Skin_Link         107 non-null    object
#  10  Found_in          107 non-null    object
#  11  Found_in_zh       107 non-null    object
#  12  Found_in_Link     107 non-null    object
#  13  Found_in_Link_zh  107 non-null    object
#  14  Type_en           107 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 13.4+ KB
#            Weapon_en      Weapon_zh       Skin_Name   Skin_Name_zh  \
# 36       Sunset Wave           落日余波
# 92    Headcrab Glyph          猎头蟹符文
# 71             Hydra            九头蛇
# 29   Entropiq (Gold)  Entropiq （金色）  Stockholm 2021  2021年斯德哥尔摩锦标赛
# 102            Bravo             英勇
#
#             Grade Rarity   Value Value_Stattrak Value_Souvenir  \
# 36   [Remarkable]    [4]  $ 3.59
# 92   [High Grade]    [3]  $ 0.64
# 71   [High Grade]    [3]  $ 0.97
# 29   [Remarkable]    [4]  $ 4.94
# 102  [High Grade]    [3]  $ 0.52
#
#                                              Skin_Link  \
# 36     https://wiki.cs.money/patches/patch-sunset-wave
# 92   https://wiki.cs.money/patches/patch-headcrab-g...
# 71           https://wiki.cs.money/patches/patch-hydra
# 29   https://wiki.cs.money/patches/patch-entropiq-g...
# 102          https://wiki.cs.money/patches/patch-bravo
#
#                                    Found_in            Found_in_zh  \
# 36     [Operation Riptide Patch Collection]         [“激流大行动”布章收藏品]
# 92             [Half-Life: Alyx Patch Pack]        [《半衰期：爱莉克斯》布章包]
# 71                       [CS:GO Patch Pack]             [CS:GO布章包]
# 29   [Stockholm 2021 Contenders Patch Pack]  [2021年斯德哥尔摩锦标赛竞争组布章包]
# 102                      [CS:GO Patch Pack]             [CS:GO布章包]
#
#                                          Found_in_Link  \
# 36   [https://wiki.cs.money/packs/operation-riptide...
# 92   [https://wiki.cs.money/packs/half-life-alyx-pa...
# 71       [https://wiki.cs.money/packs/csgo-patch-pack]
# 29   [https://wiki.cs.money/packs/stockholm-2021-co...
# 102      [https://wiki.cs.money/packs/csgo-patch-pack]
#
#                                       Found_in_Link_zh  Type_en
# 36   [https://wiki.cs.money/zh/packs/operation-ript...  Patches
# 92   [https://wiki.cs.money/zh/packs/half-life-alyx...  Patches
# 71    [https://wiki.cs.money/zh/packs/csgo-patch-pack]  Patches
# 29   [https://wiki.cs.money/zh/packs/stockholm-2021...  Patches
# 102   [https://wiki.cs.money/zh/packs/csgo-patch-pack]  Patches

# %% [markdown]
# Correcting *Tournament Stickers*
#
# The *Tournament Stickets* website is malformed. In many (but no all) items, the class that should correspond to `Skin_Name_zh`, appears as `Weapon_zh`, and the `Skin_Name_zh` field is empty. We'll have to manually correct this. If `Skin_Name_zh` is empty (but `Skin_Name` is not), move `Weapon_zh` to `Skin_Name_zh`, copy `Weapon_en` to `Weapon_zh`.

# %%
new_df_temp = pd.read_pickle("new_df_Tournament Stickers.pkl")

df_tournamentstickers = new_df_temp.copy()

# Iterate through the rows of the dataframe
for index, row in df_tournamentstickers.iterrows():
    # If the Skin_Name_zh column is empty but Skin_Name is not

    if row['Skin_Name_zh'] == "" and row['Skin_Name'] != "":
        # Move Weapon_zh to Skin_Name_zh
        df_tournamentstickers.at[index, 'Skin_Name_zh'] = row['Weapon_zh']
        # Copy the contents of Weapon_en to Weapon_zh
        df_tournamentstickers.at[index, 'Weapon_zh'] = row['Weapon_en']

display(df_tournamentstickers.sample(7))
df_tournamentstickers.to_pickle("./new_df_Tournament Stickers.pkl")
del df_tournamentstickers
del new_df_temp
# Out:
#         Weapon_en    Weapon_zh         Skin_Name     Skin_Name_zh  \
# 1403      Boombl4      Boombl4      Antwerp 2022     2022年安特卫普锦标赛
# 1255          BIG          BIG    Stockholm 2021    2021年斯德哥尔摩锦标赛
# 1382         Jame         Jame    Stockholm 2021    2021年斯德哥尔摩锦标赛
# 1200         Sico         Sico       Berlin 2019       2019年柏林锦标赛
# 308    freakazoid   freakazoid  Cluj-Napoca 2015  2015年克卢日-纳波卡锦标赛
# 1452     karrigan     karrigan      Antwerp 2022     2022年安特卫普锦标赛
# 264   olofmeister  olofmeister      Atlanta 2017     2017年亚特兰大锦标赛
# 1412        dav1d        dav1d      Antwerp 2022     2022年安特卫普锦标赛
# 558     markeloff    markeloff       Boston 2018      2018年波士顿锦标赛
# 257     markeloff    markeloff       Krakow 2017     2017年克拉科夫锦标赛
#
#                                                 Grade        Rarity   Value  \
# 1403  [High Grade, Remarkable, Exotic, Extraordinary]  [3, 4, 5, 6]  $ 0.03
# 1255  [High Grade, Remarkable, Exotic, Extraordinary]  [3, 4, 5, 6]  $ 0.04
# 1382          [High Grade, Remarkable, Extraordinary]     [3, 4, 6]  $ 0.03
# 1200          [High Grade, Remarkable, Extraordinary]     [3, 4, 6]  $ 0.08
# 308                      [High Grade, Exotic, Exotic]     [3, 5, 5]  $ 2.98
# 1452  [High Grade, Remarkable, Exotic, Extraordinary]  [3, 4, 5, 6]  $ 0.03
# 264                      [High Grade, Exotic, Exotic]     [3, 5, 5]  $ 3.75
# 1412  [High Grade, Remarkable, Exotic, Extraordinary]  [3, 4, 5, 6]  $ 0.03
# 558           [High Grade, Remarkable, Extraordinary]     [3, 4, 6]  $ 1.59
# 257           [High Grade, Remarkable, Extraordinary]     [3, 4, 6]  $ 3.82
#
#      Value_Stattrak Value_Souvenir  \
# 1403
# 1255
# 1382
# 1200
# 308
# 1452
# 264
# 1412
# 558
# 257
#
#                                               Skin_Link  \
# 1403  https://wiki.cs.money/stickers/sticker-boombl4...
# 1255  https://wiki.cs.money/stickers/sticker-big-sto...
# 1382  https://wiki.cs.money/stickers/sticker-jame-st...
# 1200  https://wiki.cs.money/stickers/sticker-sico-be...
# 308   https://wiki.cs.money/stickers/sticker-freakaz...
# 1452  https://wiki.cs.money/stickers/sticker-karriga...
# 264   https://wiki.cs.money/stickers/sticker-olofmei...
# 1412  https://wiki.cs.money/stickers/sticker-dav1d-a...
# 558   https://wiki.cs.money/stickers/sticker-markelo...
# 257   https://wiki.cs.money/stickers/sticker-markelo...
#
#                                                Found_in  \
# 1403           [Antwerp 2022 Legends Autograph Capsule]
# 1255       [Stockholm 2021 Challengers Sticker Capsule]
# 1382       [Stockholm 2021 Finalists Autograph Capsule]
# 1200  [Berlin 2019 Minor Challengers Autograph Capsule]
# 308   [Autograph Capsule | Challengers (Foil) | Cluj...
# 1452           [Antwerp 2022 Legends Autograph Capsule]
# 264   [Autograph Capsule | Legends (Foil) | Atlanta ...
# 1412        [Antwerp 2022 Contenders Autograph Capsule]
# 558   [Boston 2018 Returning Challengers Autograph C...
# 257         [Krakow 2017 Challengers Autograph Capsule]
#
#                                             Found_in_zh  \
# 1403                            [2022年安特卫普锦标赛传奇组亲笔签名胶囊]
# 1255                             [2021年斯德哥尔摩锦标赛挑战组印花胶囊]
# 1382                         [2021年斯德哥尔摩锦标赛冠军赛选手亲笔签名胶囊]
# 1200                              [2019年柏林锦标赛竞争组亲笔签名胶囊]
# 308   [亲笔签名胶囊 | 挑战组（闪亮）| 2015年克卢日-纳波卡锦标赛, 亲笔签名胶囊 | C...
# 1452                            [2022年安特卫普锦标赛传奇组亲笔签名胶囊]
# 264   [亲笔签名胶囊 | 传奇（闪亮）| 2017年亚特兰大锦标赛, 亲笔签名胶囊 | Fnati...
# 1412                            [2022年安特卫普锦标赛竞争组亲笔签名胶囊]
# 558                              [2018年波士顿锦标赛挑战组亲笔签名胶囊]
# 257                             [2017年克拉科夫锦标赛挑战组亲笔签名胶囊]
#
#                                           Found_in_Link  \
# 1403  [https://wiki.cs.money/capsules/antwerp-2022-l...
# 1255  [https://wiki.cs.money/capsules/stockholm-2021...
# 1382  [https://wiki.cs.money/capsules/stockholm-2021...
# 1200  [https://wiki.cs.money/capsules/berlin-2019-mi...
# 308   [https://wiki.cs.money/capsules/autograph-caps...
# 1452  [https://wiki.cs.money/capsules/antwerp-2022-l...
# 264   [https://wiki.cs.money/capsules/autograph-caps...
# 1412  [https://wiki.cs.money/capsules/antwerp-2022-c...
# 558   [https://wiki.cs.money/capsules/boston-2018-re...
# 257   [https://wiki.cs.money/capsules/krakow-2017-ch...
#
#                                        Found_in_Link_zh              Type_en
# 1403  [https://wiki.cs.money/zh/capsules/antwerp-202...  Tournament Stickers
# 1255  [https://wiki.cs.money/zh/capsules/stockholm-2...  Tournament Stickers
# 1382  [https://wiki.cs.money/zh/capsules/stockholm-2...  Tournament Stickers
# 1200  [https://wiki.cs.money/zh/capsules/berlin-2019...  Tournament Stickers
# 308   [https://wiki.cs.money/zh/capsules/autograph-c...  Tournament Stickers
# 1452  [https://wiki.cs.money/zh/capsules/antwerp-202...  Tournament Stickers
# 264   [https://wiki.cs.money/zh/capsules/autograph-c...  Tournament Stickers
# 1412  [https://wiki.cs.money/zh/capsules/antwerp-202...  Tournament Stickers
# 558   [https://wiki.cs.money/zh/capsules/boston-2018...  Tournament Stickers
# 257   [https://wiki.cs.money/zh/capsules/krakow-2017...  Tournament Stickers

# %% [markdown]
# Concatenate df_other pickle files

# %%
# Now load all the pickle files (they start with "new_df_*), and concatenate them
import os
df_out_other = pd.DataFrame()
files = os.listdir('./df_pickles')
for file in files:
    if file.endswith('.pkl') and file.startswith('new_df_'):
        # Load the dataframe from the pickle file
        df = pd.read_pickle(file)
        df_out_other = pd.concat([df_out_other , df], axis=0)
del df
del files

# and merge the dataframes df_other and df_other_out (the "skeleton" df that contains the categories)
df_out_other  = df_out_other.copy()
df_out_other  = df_other_out.merge(df_out_other , how='outer', left_on=['Type_en'], right_on=['Type_en'])
display(df_out_other .sample(5))

# Show number of null values for each feature
df_out_other.replace(r'^\s*$', np.nan, regex=True).info()

# Let's save it to a pickle file
df_out_other.to_pickle("./df_pickles/df_out_other.pkl")

del df_other_out
# Out:
#                   Type_en                                       Link Type_zh  \
# 930   Tournament Stickers  https://wiki.cs.money/tournament-stickers    大赛贴纸
# 79                   Keys                 https://wiki.cs.money/keys      钥匙
# 391      Regular Stickers     https://wiki.cs.money/regular-stickers    普通贴纸
# 2652             Graffiti             https://wiki.cs.money/graffiti      涂鸦
# 450      Regular Stickers     https://wiki.cs.money/regular-stickers    普通贴纸
#
#                                            Link_zh  \
# 930   https://wiki.cs.money/zh/tournament-stickers
# 79                   https://wiki.cs.money/zh/keys
# 391      https://wiki.cs.money/zh/regular-stickers
# 2652             https://wiki.cs.money/zh/graffiti
# 450      https://wiki.cs.money/zh/regular-stickers
#
#                         Weapon_en     Weapon_zh         Skin_Name  \
# 930                    freakazoid    freakazoid  Cluj-Napoca 2015
# 79    Operation Breakout Case Key  “突围大行动”武器箱钥匙
# 391                        Necron            死灵
# 2652     Mr. Teeth (Bazooka Pink)      露齿笑 (丁香)
# 450                     Vigilance           警戒者
#
#          Skin_Name_zh                         Grade     Rarity   Value  \
# 930   2015年克卢日-纳波卡锦标赛  [High Grade, Exotic, Exotic]  [3, 5, 5]  $ 2.98
# 79                                        [Default]        [1]  $ 9.92
# 391                                    [High Grade]        [3]  $ 0.46
# 2652                                   [Base Grade]        [1]  $ 0.03
# 450                        [High Grade, Remarkable]     [3, 4]  $ 0.29
#
#      Value_Stattrak Value_Souvenir  \
# 930
# 79
# 391
# 2652
# 450
#
#                                               Skin_Link  \
# 930   https://wiki.cs.money/stickers/sticker-freakaz...
# 79    https://wiki.cs.money/keys/operation-breakout-...
# 391       https://wiki.cs.money/stickers/sticker-necron
# 2652  https://wiki.cs.money/graffiti/sealed-graffiti...
# 450    https://wiki.cs.money/stickers/sticker-vigilance
#
#                                                Found_in  \
# 930   [Autograph Capsule | Challengers (Foil) | Cluj...
# 79                     [Operation Breakout Weapon Case]
# 391                  [Warhammer 40,000 Sticker Capsule]
# 2652                                                 []
# 450                                   [Sticker Capsule]
#
#                                             Found_in_zh  \
# 930   [亲笔签名胶囊 | 挑战组（闪亮）| 2015年克卢日-纳波卡锦标赛, 亲笔签名胶囊 | C...
# 79                                         [“突围大行动”武器箱]
# 391                                         [战锤40k印花胶囊]
# 2652                                                 []
# 450                                              [印花胶囊]
#
#                                           Found_in_Link  \
# 930   [https://wiki.cs.money/capsules/autograph-caps...
# 79    [https://wiki.cs.money/cases/operation-breakou...
# 391   [https://wiki.cs.money/capsules/warhammer-4000...
# 2652                                                 []
# 450    [https://wiki.cs.money/capsules/sticker-capsule]
#
#                                        Found_in_Link_zh
# 930   [https://wiki.cs.money/zh/capsules/autograph-c...
# 79    [https://wiki.cs.money/zh/cases/operation-brea...
# 391   [https://wiki.cs.money/zh/capsules/warhammer-4...
# 2652                                                 []
# 450   [https://wiki.cs.money/zh/capsules/sticker-cap...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2779 entries, 0 to 2778
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type_en           2779 non-null   object
#  1   Link              2779 non-null   object
#  2   Type_zh           2779 non-null   object
#  3   Link_zh           2779 non-null   object
#  4   Weapon_en         2779 non-null   object
#  5   Weapon_zh         2779 non-null   object
#  6   Skin_Name         1931 non-null   object
#  7   Skin_Name_zh      1924 non-null   object
#  8   Grade             2779 non-null   object
#  9   Rarity            2779 non-null   object
#  10  Value             2779 non-null   object
#  11  Value_Stattrak    0 non-null      float64
#  12  Value_Souvenir    0 non-null      float64
#  13  Skin_Link         2779 non-null   object
#  14  Found_in          2779 non-null   object
#  15  Found_in_zh       2779 non-null   object
#  16  Found_in_Link     2779 non-null   object
#  17  Found_in_Link_zh  2779 non-null   object
# dtypes: float64(2), object(16)
# memory usage: 412.5+ KB

# %% [markdown]
# ### Concatenate (`df_out_weaponskins`) & (`df_out_other`)
#
# The resulting dataframe will be `df_out`, that will correspond to the outcomes of a lootbox.

# %%
# Finally, concat the "other" dataframe with the main one:
df_out = pd.read_pickle("./df_pickles/df_out_weaponskins.pkl")
df_out = pd.concat([df_out_weaponskins, df_out_other], axis=0)
df_out.reset_index(inplace=True)

# Save to pickle
df_out.to_pickle("./df_pickles/df_out.pkl")

# %%
# Show number of null values for each feature
df_out.replace(r'^\s*$', np.nan, regex=True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4403 entries, 0 to 4402
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             4403 non-null   int64
#  1   Type_en           4402 non-null   object
#  2   Type_zh           4402 non-null   object
#  3   Weapon_en         4403 non-null   object
#  4   Weapon_zh         4403 non-null   object
#  5   Image             1623 non-null   object
#  6   Link              4402 non-null   object
#  7   Skin_Name         3555 non-null   object
#  8   Skin_Name_zh      3548 non-null   object
#  9   Grade             4403 non-null   object
#  10  Rarity            4403 non-null   object
#  11  Value             4403 non-null   object
#  12  Value_Stattrak    1106 non-null   object
#  13  Value_Souvenir    248 non-null    object
#  14  Skin_Link         4403 non-null   object
#  15  Found_in          4403 non-null   object
#  16  Found_in_zh       4403 non-null   object
#  17  Found_in_Link     4403 non-null   object
#  18  Found_in_Link_zh  4403 non-null   object
#  19  Link_zh           2779 non-null   object
# dtypes: int64(1), object(19)
# memory usage: 688.1+ KB

# %%
# Check if things change if we remove duplicates
# (This weird line is because some features contains list, and drop_duplicates can't work with them. So we convert everything to strings first)

df_out.loc[df_out.astype(str).drop_duplicates().index].replace(r'^\s*$', np.nan, regex=True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4403 entries, 0 to 4402
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             4403 non-null   int64
#  1   Type_en           4402 non-null   object
#  2   Type_zh           4402 non-null   object
#  3   Weapon_en         4403 non-null   object
#  4   Weapon_zh         4403 non-null   object
#  5   Image             1623 non-null   object
#  6   Link              4402 non-null   object
#  7   Skin_Name         3555 non-null   object
#  8   Skin_Name_zh      3548 non-null   object
#  9   Grade             4403 non-null   object
#  10  Rarity            4403 non-null   object
#  11  Value             4403 non-null   object
#  12  Value_Stattrak    1106 non-null   object
#  13  Value_Souvenir    248 non-null    object
#  14  Skin_Link         4403 non-null   object
#  15  Found_in          4403 non-null   object
#  16  Found_in_zh       4403 non-null   object
#  17  Found_in_Link     4403 non-null   object
#  18  Found_in_Link_zh  4403 non-null   object
#  19  Link_zh           2779 non-null   object
# dtypes: int64(1), object(19)
# memory usage: 722.4+ KB

# %% [markdown]
# ## Scraping lootbox cases (src)

# %% [markdown]
# ### Manually select categories to scrape
#
# Since the website is quite inconsistent and not all info is necessary, we'll define the categories manually.

# %%
# list of lootbox types that you can purchase, except weapon skins, and URLs
other_src = {
    'Cases': 'https://wiki.cs.money/cases', 
    'Collections': 'https://wiki.cs.money/collections', 
    'Souvenir Packages': 'https://wiki.cs.money/souvenir-packages',
    'Agent Collections':'https://wiki.cs.money/agent-collections',
    'Sticker Capsules':'https://wiki.cs.money/capsules',
    'Patch Packs':'https://wiki.cs.money/packs',
    'Graffiti Capsules':'https://wiki.cs.money/graffiti-capsules',
    'Music Kit Boxes':'https://wiki.cs.money/music-kit-boxes',
    'Pins Capsules':'https://wiki.cs.money/pins-capsules'
} 

df_other_src = pd.DataFrame.from_dict(other_src, orient='index', columns=['Link'])
df_other_src.reset_index(inplace=True)
df_other_src = df_other_src.rename(columns={"index": "Type_en"})
#df_other_out['Link_zh'] = df_other_out.apply(lambda row : convert_url(row['Link'], 'zh'), axis=1) # not necessary, will only add clutter.

other_src_zh = {
    '案件':'https://wiki.cs.money/zh/cases',
    '藏品':'https://wiki.cs.money/zh/collections',
    '纪念品包':'https://wiki.cs.money/zh/souvenir-packages',
    '探员系列':'https://wiki.cs.money/zh/agent-collections',
    '印花胶囊':'https://wiki.cs.money/zh/capsules',
    '布章包':'https://wiki.cs.money/zh/packs',
    '涂鸦胶囊':'https://wiki.cs.money/zh/graffiti-capsules',
    '音乐盒箱子':'https://wiki.cs.money/zh/music-kit-boxes',
    '勋章胶囊':'https://wiki.cs.money/zh/pins-capsules'
}

df_other_src_zh = pd.DataFrame.from_dict(other_src_zh, orient='index', columns=['Link_zh'])
df_other_src_zh.reset_index(inplace=True)
df_other_src_zh = df_other_src_zh.rename(columns={"index": "Type_zh"})

df_other_src = pd.concat([df_other_src, df_other_src_zh], axis=1)

display(df_other_src)
# Out:
#              Type_en                                     Link Type_zh  \
# 0              Cases              https://wiki.cs.money/cases      案件
# 1        Collections        https://wiki.cs.money/collections      藏品
# 2  Souvenir Packages  https://wiki.cs.money/souvenir-packages    纪念品包
# 3  Agent Collections  https://wiki.cs.money/agent-collections    探员系列
# 4   Sticker Capsules           https://wiki.cs.money/capsules    印花胶囊
# 5        Patch Packs              https://wiki.cs.money/packs     布章包
# 6  Graffiti Capsules  https://wiki.cs.money/graffiti-capsules    涂鸦胶囊
# 7    Music Kit Boxes    https://wiki.cs.money/music-kit-boxes   音乐盒箱子
# 8      Pins Capsules      https://wiki.cs.money/pins-capsules    勋章胶囊
#
#                                       Link_zh
# 0              https://wiki.cs.money/zh/cases
# 1        https://wiki.cs.money/zh/collections
# 2  https://wiki.cs.money/zh/souvenir-packages
# 3  https://wiki.cs.money/zh/agent-collections
# 4           https://wiki.cs.money/zh/capsules
# 5              https://wiki.cs.money/zh/packs
# 6  https://wiki.cs.money/zh/graffiti-capsules
# 7    https://wiki.cs.money/zh/music-kit-boxes
# 8      https://wiki.cs.money/zh/pins-capsules

# %% [markdown]
# ### Scrape the lootbox cases from the website

# %%
# For each one of the other_src, do what we did for Skins. Can take around a minute.
df_src = pd.DataFrame()
for key, value in other_src.items():
    print(key)
    print(value)
    new_df = get_skin_info(value)
    new_df['Type_en'] = key
    df_src = pd.concat([df_src, new_df], axis=0)
del new_df

# and merge the dataframes df_other and df_other_src
df_src = df_src.copy()
df_src = df_other_src.merge(df_src, how='outer', left_on=['Type_en'], right_on=['Type_en'])
display(df_src)
# Out:
# Cases
# https://wiki.cs.money/cases
# https://wiki.cs.money/zh/cases
# Collections
# https://wiki.cs.money/collections
# https://wiki.cs.money/zh/collections
# Souvenir Packages
# https://wiki.cs.money/souvenir-packages
# https://wiki.cs.money/zh/souvenir-packages
# Agent Collections
# https://wiki.cs.money/agent-collections
# https://wiki.cs.money/zh/agent-collections
# Sticker Capsules
# https://wiki.cs.money/capsules
# https://wiki.cs.money/zh/capsules
# Patch Packs
# https://wiki.cs.money/packs
# https://wiki.cs.money/zh/packs
# Graffiti Capsules
# https://wiki.cs.money/graffiti-capsules
# reached end
# https://wiki.cs.money/zh/graffiti-capsules
# reached end
# Music Kit Boxes
# https://wiki.cs.money/music-kit-boxes
# https://wiki.cs.money/zh/music-kit-boxes
# Pins Capsules
# https://wiki.cs.money/pins-capsules
# reached end
# https://wiki.cs.money/zh/pins-capsules
# reached end
#              Type_en                                   Link Type_zh  \
# 0              Cases            https://wiki.cs.money/cases      案件
# 1              Cases            https://wiki.cs.money/cases      案件
# 2              Cases            https://wiki.cs.money/cases      案件
# 3              Cases            https://wiki.cs.money/cases      案件
# 4              Cases            https://wiki.cs.money/cases      案件
# ..               ...                                    ...     ...
# 158  Music Kit Boxes  https://wiki.cs.money/music-kit-boxes   音乐盒箱子
# 159    Pins Capsules    https://wiki.cs.money/pins-capsules    勋章胶囊
# 160    Pins Capsules    https://wiki.cs.money/pins-capsules    勋章胶囊
# 161    Pins Capsules    https://wiki.cs.money/pins-capsules    勋章胶囊
# 162    Pins Capsules    https://wiki.cs.money/pins-capsules    勋章胶囊
#
#                                       Link_zh  \
# 0              https://wiki.cs.money/zh/cases
# 1              https://wiki.cs.money/zh/cases
# 2              https://wiki.cs.money/zh/cases
# 3              https://wiki.cs.money/zh/cases
# 4              https://wiki.cs.money/zh/cases
# ..                                        ...
# 158  https://wiki.cs.money/zh/music-kit-boxes
# 159    https://wiki.cs.money/zh/pins-capsules
# 160    https://wiki.cs.money/zh/pins-capsules
# 161    https://wiki.cs.money/zh/pins-capsules
# 162    https://wiki.cs.money/zh/pins-capsules
#
#                                     Weapon_en         Weapon_zh Skin_Name  \
# 0                             Revolution Case   Revolution Case
# 1                                 Recoil Case       Recoil Case
# 2                    Dreams & Nightmares Case             梦魇武器箱
# 3                      Operation Riptide Case        “激流大行动”武器箱
# 4                              Snakebite Case             蛇噬武器箱
# ..                                        ...               ...       ...
# 158                 Masterminds Music Kit Box          决策大师音乐盒集
# 159         Collectible Pins Capsule Series 1       系列 1 收藏胸章胶囊
# 160         Collectible Pins Capsule Series 2       系列 2 收藏胸章胶囊
# 161  Half-Life: Alyx Collectible Pins Capsule  《半衰期：爱莉克斯》收藏胸章胶囊
# 162         Collectible Pins Capsule Series 3       系列 3 收藏胸章胶囊
#
#     Skin_Name_zh      Grade Rarity    Value Value_Stattrak Value_Souvenir  \
# 0                 [Default]    [1]   $ 6.30
# 1                 [Default]    [1]   $ 0.57
# 2                 [Default]    [1]   $ 0.50
# 3                 [Default]    [1]   $ 1.82
# 4                 [Default]    [1]   $ 0.12
# ..           ...        ...    ...      ...            ...            ...
# 158               [Default]    [1]   $ 6.37
# 159               [Default]    [1]  $ 12.21
# 160               [Default]    [1]  $ 11.69
# 161               [Default]    [1]  $ 11.42
# 162               [Default]    [1]  $ 11.32
#
#                                              Skin_Link Found_in Found_in_zh  \
# 0          https://wiki.cs.money/cases/revolution-case       []          []
# 1              https://wiki.cs.money/cases/recoil-case       []          []
# 2    https://wiki.cs.money/cases/dreams-nightmares-...       []          []
# 3    https://wiki.cs.money/cases/operation-riptide-...       []          []
# 4           https://wiki.cs.money/cases/snakebite-case       []          []
# ..                                                 ...      ...         ...
# 158  https://wiki.cs.money/music-kit-boxes/mastermi...       []          []
# 159  https://wiki.cs.money/pins-capsules/collectibl...       []          []
# 160  https://wiki.cs.money/pins-capsules/collectibl...       []          []
# 161  https://wiki.cs.money/pins-capsules/half-life-...       []          []
# 162  https://wiki.cs.money/pins-capsules/collectibl...       []          []
#
#     Found_in_Link Found_in_Link_zh
# 0              []               []
# 1              []               []
# 2              []               []
# 3              []               []
# 4              []               []
# ..            ...              ...
# 158            []               []
# 159            []               []
# 160            []               []
# 161            []               []
# 162            []               []
#
# [163 rows x 18 columns]

# %%
# Show number of null values for each feature
df_src.replace(r'^\s*$', np.nan, regex=True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 162
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type_en           163 non-null    object
#  1   Link              163 non-null    object
#  2   Type_zh           163 non-null    object
#  3   Link_zh           163 non-null    object
#  4   Weapon_en         163 non-null    object
#  5   Weapon_zh         163 non-null    object
#  6   Skin_Name         0 non-null      float64
#  7   Skin_Name_zh      0 non-null      float64
#  8   Grade             163 non-null    object
#  9   Rarity            163 non-null    object
#  10  Value             74 non-null     object
#  11  Value_Stattrak    0 non-null      float64
#  12  Value_Souvenir    0 non-null      float64
#  13  Skin_Link         163 non-null    object
#  14  Found_in          163 non-null    object
#  15  Found_in_zh       163 non-null    object
#  16  Found_in_Link     163 non-null    object
#  17  Found_in_Link_zh  163 non-null    object
# dtypes: float64(4), object(14)
# memory usage: 24.2+ KB

# %% [markdown]
# ### Drop unused columns in `df_src` dataframe

# %%
df_src = df_src.rename(columns={
    'Weapon_en': 'lootbox_en',
    'Weapon_zh': 'lootbox_zh'
})

df_src = df_src.drop(columns=['Skin_Name', 'Skin_Name_zh', 'Value_Stattrak', 'Value_Souvenir', 'Found_in', 'Found_in_zh', 'Found_in_Link', 'Found_in_Link_zh'])

display(df_src.sample(5))


# Let's save it to a file
df_src.to_pickle("./df_pickles/df_src.pkl")
# Out:
#               Type_en                               Link Type_zh  \
# 1               Cases        https://wiki.cs.money/cases      案件
# 9               Cases        https://wiki.cs.money/cases      案件
# 44        Collections  https://wiki.cs.money/collections      藏品
# 72        Collections  https://wiki.cs.money/collections      藏品
# 126  Sticker Capsules     https://wiki.cs.money/capsules    印花胶囊
#
#                                   Link_zh                        lootbox_en  \
# 1          https://wiki.cs.money/zh/cases                       Recoil Case
# 9          https://wiki.cs.money/zh/cases                         CS20 Case
# 44   https://wiki.cs.money/zh/collections        The Danger Zone Collection
# 72   https://wiki.cs.money/zh/collections           The Huntsman Collection
# 126     https://wiki.cs.money/zh/capsules  Rio 2022 Legends Sticker Capsule
#
#                            lootbox_zh      Grade Rarity   Value  \
# 1                         Recoil Case  [Default]    [1]  $ 0.57
# 9                         反恐精英20周年武器箱  [Default]    [1]  $ 0.17
# 44                            头号特训收藏品  [Default]    [1]
# 72                             猎杀者收藏品  [Default]    [1]
# 126  Rio 2022 Legends Sticker Capsule  [Default]    [1]       —
#
#                                              Skin_Link
# 1              https://wiki.cs.money/cases/recoil-case
# 9                https://wiki.cs.money/cases/cs20-case
# 44   https://wiki.cs.money/collections/the-danger-z...
# 72   https://wiki.cs.money/collections/the-huntsman...
# 126  https://wiki.cs.money/capsules/rio-2022-legend...

# %% [markdown]
# ### Missing translations in df_src
#
# The `src` column in the purchases dataset seems to be equivalent to the `lootbox_zh` field in the lootbox dataframe `df_src`
#
# However, `df_src` has some missing translations, that we'll add manually.

# %%
# import from json file
import json
with open('./lootbox_addiction/lootbox_db_scraping/lootboxes_zh_en.json', 'r', encoding='utf-8') as file:
    lootboxes_zh_en = json.load(file)
display(lootboxes_zh_en)

# Same dict, opposite direction (English->Chinese)
lootboxes_en_zh = {v: k for k, v in lootboxes_zh_en.items()}

df_src['lootbox_zh'] = df_src['lootbox_zh'].map(lootboxes_en_zh).fillna(df_src['lootbox_zh'])

df_src.to_pickle("./df_pickles/df_src.pkl")

# %% [markdown]
# Done. In the `df_pickles` folder there should be a `df_src` with information about the lootbox cases, and `df_out` with information about the lootbox outcomes, including their value. The rest of the .pkl files at this point are redundant, but can be used to reconstruct these two dataframes from partial data if necessary.
